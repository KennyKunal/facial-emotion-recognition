# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
train_dir = r"C:\Users\Acer\Desktop\fer2013\train" # Directory containing the training data
test_dir = r"C:\Users\Acer\Desktop\fer2013\test"  # Directory containing the validation data

# %%
train_datagen = ImageDataGenerator(
    width_shift_range = 0.1,        # Randomly shift the width of images by up to 10%
    height_shift_range = 0.1,       # Randomly shift the height of images by up to 10%
    horizontal_flip = True,         # Flip images horizontally at random
    rescale = 1./255,               # Rescale pixel values to be between 0 and 1
    validation_split = 0.2          # Set aside 20% of the data for validation
)

validation_datagen = ImageDataGenerator(
    rescale = 1./255,               # Rescale pixel values to be between 0 and 1
    validation_split = 0.2          # Set aside 20% of the data for validation
)

# %%
train_generator = train_datagen.flow_from_directory(
    directory = train_dir,           # Directory containing the training data
    target_size = (48, 48),          # Resizes all images to 48x48 pixels
    batch_size = 64,                 # Number of images per batch
    color_mode = "grayscale",        # Converts the images to grayscale
    class_mode = "categorical",      # Classifies the images into 7 categories
    subset = "training"              # Uses the training subset of the data
)

validation_generator = validation_datagen.flow_from_directory(
    directory = test_dir,            # Directory containing the validation data
    target_size = (48, 48),          # Resizes all images to 48x48 pixels
    batch_size = 64,                 # Number of images per batch
     color_mode = "grayscale",        # Converts the images to grayscale
    class_mode = "categorical",      # Classifies the images into 7 categories
    subset = "validation"            # Uses the validation subset of the data
)
# Out:
# Found 22968 images belonging to 7 classes.
# Found 1432 images belonging to 7 classes.

# %%
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.models import Sequential
import tensorflow as tf 

# Define the model architecture
model = Sequential()

# Add a convolutional layer with 32 filters, 3x3 kernel size, and relu activation function
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(48,48,1)))
# Add a batch normalization layer
model.add(BatchNormalization())
# Add a second convolutional layer with 64 filters, 3x3 kernel size, and relu activation function
model.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
# Add a second batch normalization layer
model.add(BatchNormalization())
# Add a max pooling layer with 2x2 pool size
model.add(MaxPooling2D(pool_size=(2, 2)))
# Add a dropout layer with 0.25 dropout rate
model.add(Dropout(0.25))

# Add a third convolutional layer with 128 filters, 3x3 kernel size, and relu activation function
model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
# Add a third batch normalization layer
model.add(BatchNormalization())
# Add a fourth convolutional layer with 128 filters, 3x3 kernel size, and relu activation function
model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
# Add a fourth batch normalization layer
model.add(BatchNormalization())
# Add a max pooling layer with 2x2 pool size
model.add(MaxPooling2D(pool_size=(2, 2)))
# Add a dropout layer with 0.25 dropout rate
model.add(Dropout(0.25))

# Add a fifth convolutional layer with 256 filters, 3x3 kernel size, and relu activation function
model.add(Conv2D(256, kernel_size=(3, 3), activation='relu'))
# Add a fifth batch normalization layer
model.add(BatchNormalization())
# Add a sixth convolutional layer with 256 filters, 3x3 kernel size, and relu activation function
model.add(Conv2D(256, kernel_size=(3, 3), activation='relu'))
# Add a sixth batch normalization layer
model.add(BatchNormalization())
# Add a max pooling layer with 2x2 pool size
model.add(MaxPooling2D(pool_size=(2, 2)))
# Add a dropout layer with 0.25 dropout rate
model.add(Dropout(0.25))

# Flatten the output of the convolutional layers
model.add(Flatten())
# Add a dense layer with 256 neurons and relu activation function
model.add(Dense(256, activation='relu'))
# Add a seventh batch normalization layer
model.add(BatchNormalization())
# Add a dropout layer with 0.5 dropout rate
model.add(Dropout(0.5))
# Add a dense layer with 7 neurons (one for each class) and softmax activation function
model.add(Dense(7, activation='softmax'))

# Compile the model with categorical cross-entropy loss, adam optimizer, and accuracy metric
model.compile(loss="categorical_crossentropy", optimizer= tf.keras.optimizers.Adam(lr=0.0001), metrics=['accuracy'])
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.

# %%
from tensorflow.keras.callbacks import ModelCheckpoint

# Define the callback
checkpoint_callback = ModelCheckpoint(
    filepath='model_weights.h5',
    monitor='val_accuracy',
    save_best_only=True,
    save_weights_only=True,
    mode='max',
    verbose=1
)

# Train the model with the callback
history = model.fit(
    train_generator,
    steps_per_epoch=len(train_generator),
    epochs=50,
    validation_data=validation_generator,
    validation_steps=len(validation_generator),
    callbacks=[checkpoint_callback]
)
# Out:
# Epoch 1/50
# 359/359 [==============================] - ETA: 0s - loss: 2.1722 - accuracy: 0.2452
# Epoch 1: val_accuracy improved from -inf to 0.29050, saving model to model_weights.h5
# 359/359 [==============================] - 435s 1s/step - loss: 2.1722 - accuracy: 0.2452 - val_loss: 1.8227 - val_accuracy: 0.2905
# Epoch 2/50
# 359/359 [==============================] - ETA: 0s - loss: 1.6674 - accuracy: 0.3682
# Epoch 2: val_accuracy improved from 0.29050 to 0.40154, saving model to model_weights.h5
# 359/359 [==============================] - 516s 1s/step - loss: 1.6674 - accuracy: 0.3682 - val_loss: 1.5006 - val_accuracy: 0.4015
# Epoch 3/50
# 359/359 [==============================] - ETA: 0s - loss: 1.4627 - accuracy: 0.4402
# Epoch 3: val_accuracy improved from 0.40154 to 0.47626, saving model to model_weights.h5
# 359/359 [==============================] - 496s 1s/step - loss: 1.4627 - accuracy: 0.4402 - val_loss: 1.3725 - val_accuracy: 0.4763
# Epoch 4/50
# 359/359 [==============================] - ETA: 0s - loss: 1.3527 - accuracy: 0.4820
# Epoch 4: val_accuracy did not improve from 0.47626
# 359/359 [==============================] - 547s 2s/step - loss: 1.3527 - accuracy: 0.4820 - val_loss: 1.4224 - val_accuracy: 0.4721
# Epoch 5/50
# 359/359 [==============================] - ETA: 0s - loss: 1.2925 - accuracy: 0.5108
# Epoch 5: val_accuracy improved from 0.47626 to 0.52304, saving model to model_weights.h5
# 359/359 [==============================] - 500s 1s/step - loss: 1.2925 - accuracy: 0.5108 - val_loss: 1.2693 - val_accuracy: 0.5230
# Epoch 6/50
# 359/359 [==============================] - ETA: 0s - loss: 1.2423 - accuracy: 0.5296
# Epoch 6: val_accuracy improved from 0.52304 to 0.55168, saving model to model_weights.h5
# 359/359 [==============================] - 494s 1s/step - loss: 1.2423 - accuracy: 0.5296 - val_loss: 1.2232 - val_accuracy: 0.5517
# Epoch 7/50
# 359/359 [==============================] - ETA: 0s - loss: 1.2121 - accuracy: 0.5445
# Epoch 7: val_accuracy improved from 0.55168 to 0.58450, saving model to model_weights.h5
# 359/359 [==============================] - 486s 1s/step - loss: 1.2121 - accuracy: 0.5445 - val_loss: 1.1094 - val_accuracy: 0.5845
# Epoch 8/50
# 359/359 [==============================] - ETA: 0s - loss: 1.1802 - accuracy: 0.5521
# Epoch 8: val_accuracy did not improve from 0.58450
# 359/359 [==============================] - 479s 1s/step - loss: 1.1802 - accuracy: 0.5521 - val_loss: 1.1653 - val_accuracy: 0.5649
# Epoch 9/50
# 359/359 [==============================] - ETA: 0s - loss: 1.1567 - accuracy: 0.5675
# Epoch 9: val_accuracy improved from 0.58450 to 0.58520, saving model to model_weights.h5
# 359/359 [==============================] - 497s 1s/step - loss: 1.1567 - accuracy: 0.5675 - val_loss: 1.1356 - val_accuracy: 0.5852
# Epoch 10/50
# 359/359 [==============================] - ETA: 0s - loss: 1.1348 - accuracy: 0.5733
# Epoch 10: val_accuracy did not improve from 0.58520
# 359/359 [==============================] - 489s 1s/step - loss: 1.1348 - accuracy: 0.5733 - val_loss: 1.1427 - val_accuracy: 0.5761
# Epoch 11/50
# 359/359 [==============================] - ETA: 0s - loss: 1.1188 - accuracy: 0.5788
# Epoch 11: val_accuracy improved from 0.58520 to 0.59497, saving model to model_weights.h5
# 359/359 [==============================] - 454s 1s/step - loss: 1.1188 - accuracy: 0.5788 - val_loss: 1.0866 - val_accuracy: 0.5950
# Epoch 12/50
# 359/359 [==============================] - ETA: 0s - loss: 1.0860 - accuracy: 0.5915
# Epoch 12: val_accuracy improved from 0.59497 to 0.61243, saving model to model_weights.h5
# 359/359 [==============================] - 434s 1s/step - loss: 1.0860 - accuracy: 0.5915 - val_loss: 1.0290 - val_accuracy: 0.6124
# Epoch 13/50
# 359/359 [==============================] - ETA: 0s - loss: 1.0752 - accuracy: 0.5950
# Epoch 13: val_accuracy did not improve from 0.61243
# 359/359 [==============================] - 423s 1s/step - loss: 1.0752 - accuracy: 0.5950 - val_loss: 1.0657 - val_accuracy: 0.6013
# Epoch 14/50
# 359/359 [==============================] - ETA: 0s - loss: 1.0667 - accuracy: 0.5983
# Epoch 14: val_accuracy improved from 0.61243 to 0.62779, saving model to model_weights.h5
# 359/359 [==============================] - 405s 1s/step - loss: 1.0667 - accuracy: 0.5983 - val_loss: 1.0114 - val_accuracy: 0.6278
# Epoch 15/50
# 359/359 [==============================] - ETA: 0s - loss: 1.0505 - accuracy: 0.6050
# Epoch 15: val_accuracy did not improve from 0.62779
# 359/359 [==============================] - 404s 1s/step - loss: 1.0505 - accuracy: 0.6050 - val_loss: 1.0509 - val_accuracy: 0.6096
# Epoch 16/50
# 359/359 [==============================] - ETA: 0s - loss: 1.0293 - accuracy: 0.6152
# Epoch 16: val_accuracy did not improve from 0.62779
# 359/359 [==============================] - 406s 1s/step - loss: 1.0293 - accuracy: 0.6152 - val_loss: 1.0110 - val_accuracy: 0.6250
# Epoch 17/50
# 359/359 [==============================] - ETA: 0s - loss: 1.0117 - accuracy: 0.6198
# Epoch 17: val_accuracy improved from 0.62779 to 0.63338, saving model to model_weights.h5
# 359/359 [==============================] - 427s 1s/step - loss: 1.0117 - accuracy: 0.6198 - val_loss: 1.0040 - val_accuracy: 0.6334
# Epoch 18/50
# 359/359 [==============================] - ETA: 0s - loss: 1.0018 - accuracy: 0.6280
# Epoch 18: val_accuracy did not improve from 0.63338
# 359/359 [==============================] - 427s 1s/step - loss: 1.0018 - accuracy: 0.6280 - val_loss: 1.0126 - val_accuracy: 0.6110
# Epoch 19/50
# 359/359 [==============================] - ETA: 0s - loss: 0.9928 - accuracy: 0.6305
# Epoch 19: val_accuracy improved from 0.63338 to 0.63617, saving model to model_weights.h5
# 359/359 [==============================] - 423s 1s/step - loss: 0.9928 - accuracy: 0.6305 - val_loss: 1.0064 - val_accuracy: 0.6362
# Epoch 20/50
# 359/359 [==============================] - ETA: 0s - loss: 0.9795 - accuracy: 0.6354
# Epoch 20: val_accuracy did not improve from 0.63617
# 359/359 [==============================] - 422s 1s/step - loss: 0.9795 - accuracy: 0.6354 - val_loss: 1.0085 - val_accuracy: 0.6313
# Epoch 21/50
# 359/359 [==============================] - ETA: 0s - loss: 0.9698 - accuracy: 0.6371
# Epoch 21: val_accuracy did not improve from 0.63617
# 359/359 [==============================] - 421s 1s/step - loss: 0.9698 - accuracy: 0.6371 - val_loss: 0.9623 - val_accuracy: 0.6341
# Epoch 22/50
# 359/359 [==============================] - ETA: 0s - loss: 0.9617 - accuracy: 0.6417
# Epoch 22: val_accuracy did not improve from 0.63617
# 359/359 [==============================] - 432s 1s/step - loss: 0.9617 - accuracy: 0.6417 - val_loss: 0.9739 - val_accuracy: 0.6341
# Epoch 23/50
# 359/359 [==============================] - ETA: 0s - loss: 0.9367 - accuracy: 0.6483
# Epoch 23: val_accuracy improved from 0.63617 to 0.63757, saving model to model_weights.h5
# 359/359 [==============================] - 425s 1s/step - loss: 0.9367 - accuracy: 0.6483 - val_loss: 0.9971 - val_accuracy: 0.6376
# Epoch 24/50
# 359/359 [==============================] - ETA: 0s - loss: 0.9272 - accuracy: 0.6527
# Epoch 24: val_accuracy improved from 0.63757 to 0.65014, saving model to model_weights.h5
# 359/359 [==============================] - 421s 1s/step - loss: 0.9272 - accuracy: 0.6527 - val_loss: 0.9844 - val_accuracy: 0.6501
# Epoch 25/50
# 359/359 [==============================] - ETA: 0s - loss: 0.9194 - accuracy: 0.6576
# Epoch 25: val_accuracy did not improve from 0.65014
# 359/359 [==============================] - 427s 1s/step - loss: 0.9194 - accuracy: 0.6576 - val_loss: 1.0189 - val_accuracy: 0.6369
# Epoch 26/50
# 359/359 [==============================] - ETA: 0s - loss: 0.9100 - accuracy: 0.6626
# Epoch 26: val_accuracy did not improve from 0.65014
# 359/359 [==============================] - 430s 1s/step - loss: 0.9100 - accuracy: 0.6626 - val_loss: 0.9477 - val_accuracy: 0.6446
# Epoch 27/50
# 359/359 [==============================] - ETA: 0s - loss: 0.8979 - accuracy: 0.6678
# Epoch 27: val_accuracy improved from 0.65014 to 0.66550, saving model to model_weights.h5
# 359/359 [==============================] - 436s 1s/step - loss: 0.8979 - accuracy: 0.6678 - val_loss: 0.9313 - val_accuracy: 0.6655
# Epoch 28/50
# 359/359 [==============================] - ETA: 0s - loss: 0.8859 - accuracy: 0.6682
# Epoch 28: val_accuracy did not improve from 0.66550
# 359/359 [==============================] - 433s 1s/step - loss: 0.8859 - accuracy: 0.6682 - val_loss: 0.9993 - val_accuracy: 0.6355
# Epoch 29/50
# 359/359 [==============================] - ETA: 0s - loss: 0.8845 - accuracy: 0.6685
# Epoch 29: val_accuracy did not improve from 0.66550
# 359/359 [==============================] - 430s 1s/step - loss: 0.8845 - accuracy: 0.6685 - val_loss: 0.9766 - val_accuracy: 0.6453
# Epoch 30/50
# 359/359 [==============================] - ETA: 0s - loss: 0.8631 - accuracy: 0.6807
# Epoch 30: val_accuracy did not improve from 0.66550
# 359/359 [==============================] - 431s 1s/step - loss: 0.8631 - accuracy: 0.6807 - val_loss: 0.9515 - val_accuracy: 0.6432
# Epoch 31/50
# 359/359 [==============================] - ETA: 0s - loss: 0.8647 - accuracy: 0.6766
# Epoch 31: val_accuracy did not improve from 0.66550
# 359/359 [==============================] - 434s 1s/step - loss: 0.8647 - accuracy: 0.6766 - val_loss: 0.9305 - val_accuracy: 0.6613
# Epoch 32/50
# 359/359 [==============================] - ETA: 0s - loss: 0.8489 - accuracy: 0.6854
# Epoch 32: val_accuracy did not improve from 0.66550
# 359/359 [==============================] - 431s 1s/step - loss: 0.8489 - accuracy: 0.6854 - val_loss: 0.9485 - val_accuracy: 0.6585
# Epoch 33/50
# 359/359 [==============================] - ETA: 0s - loss: 0.8497 - accuracy: 0.6830
# Epoch 33: val_accuracy did not improve from 0.66550
# 359/359 [==============================] - 434s 1s/step - loss: 0.8497 - accuracy: 0.6830 - val_loss: 0.9683 - val_accuracy: 0.6550
# Epoch 34/50
# 359/359 [==============================] - ETA: 0s - loss: 0.8310 - accuracy: 0.6915
# Epoch 34: val_accuracy improved from 0.66550 to 0.66899, saving model to model_weights.h5
# 359/359 [==============================] - 432s 1s/step - loss: 0.8310 - accuracy: 0.6915 - val_loss: 0.9170 - val_accuracy: 0.6690
# Epoch 35/50
# 359/359 [==============================] - ETA: 0s - loss: 0.8220 - accuracy: 0.6956
# Epoch 35: val_accuracy did not improve from 0.66899
# 359/359 [==============================] - 435s 1s/step - loss: 0.8220 - accuracy: 0.6956 - val_loss: 0.9464 - val_accuracy: 0.6662
# Epoch 36/50
# 359/359 [==============================] - ETA: 0s - loss: 0.8225 - accuracy: 0.6981
# Epoch 36: val_accuracy did not improve from 0.66899
# 359/359 [==============================] - 437s 1s/step - loss: 0.8225 - accuracy: 0.6981 - val_loss: 0.9542 - val_accuracy: 0.6564
# Epoch 37/50
# 359/359 [==============================] - ETA: 0s - loss: 0.8052 - accuracy: 0.6978
# Epoch 37: val_accuracy did not improve from 0.66899
# 359/359 [==============================] - 434s 1s/step - loss: 0.8052 - accuracy: 0.6978 - val_loss: 0.9453 - val_accuracy: 0.6592
# Epoch 38/50
# 359/359 [==============================] - ETA: 0s - loss: 0.7995 - accuracy: 0.7055
# Epoch 38: val_accuracy did not improve from 0.66899
# 359/359 [==============================] - 438s 1s/step - loss: 0.7995 - accuracy: 0.7055 - val_loss: 1.0042 - val_accuracy: 0.6466
# Epoch 39/50
# 359/359 [==============================] - ETA: 0s - loss: 0.7935 - accuracy: 0.7045
# Epoch 39: val_accuracy did not improve from 0.66899
# 359/359 [==============================] - 441s 1s/step - loss: 0.7935 - accuracy: 0.7045 - val_loss: 0.9957 - val_accuracy: 0.6473
# Epoch 40/50
# 359/359 [==============================] - ETA: 0s - loss: 0.7878 - accuracy: 0.7061
# Epoch 40: val_accuracy did not improve from 0.66899
# 359/359 [==============================] - 440s 1s/step - loss: 0.7878 - accuracy: 0.7061 - val_loss: 0.9643 - val_accuracy: 0.6453
# Epoch 41/50
# 359/359 [==============================] - ETA: 0s - loss: 0.7832 - accuracy: 0.7069
# Epoch 41: val_accuracy did not improve from 0.66899
# 359/359 [==============================] - 438s 1s/step - loss: 0.7832 - accuracy: 0.7069 - val_loss: 0.9219 - val_accuracy: 0.6690
# Epoch 42/50
# 359/359 [==============================] - ETA: 0s - loss: 0.7745 - accuracy: 0.7139
# Epoch 42: val_accuracy did not improve from 0.66899
# 359/359 [==============================] - 434s 1s/step - loss: 0.7745 - accuracy: 0.7139 - val_loss: 0.9587 - val_accuracy: 0.6466
# Epoch 43/50
# 359/359 [==============================] - ETA: 0s - loss: 0.7612 - accuracy: 0.7158
# Epoch 43: val_accuracy did not improve from 0.66899
# 359/359 [==============================] - 433s 1s/step - loss: 0.7612 - accuracy: 0.7158 - val_loss: 0.9286 - val_accuracy: 0.6627
# Epoch 44/50
# 359/359 [==============================] - ETA: 0s - loss: 0.7587 - accuracy: 0.7217
# Epoch 44: val_accuracy did not improve from 0.66899
# 359/359 [==============================] - 434s 1s/step - loss: 0.7587 - accuracy: 0.7217 - val_loss: 0.9751 - val_accuracy: 0.6466
# Epoch 45/50
# 359/359 [==============================] - ETA: 0s - loss: 0.7435 - accuracy: 0.7255
# Epoch 45: val_accuracy did not improve from 0.66899
# 359/359 [==============================] - 429s 1s/step - loss: 0.7435 - accuracy: 0.7255 - val_loss: 0.9522 - val_accuracy: 0.6508
# Epoch 46/50
# 359/359 [==============================] - ETA: 0s - loss: 0.7485 - accuracy: 0.7183
# Epoch 46: val_accuracy improved from 0.66899 to 0.68366, saving model to model_weights.h5
# 359/359 [==============================] - 433s 1s/step - loss: 0.7485 - accuracy: 0.7183 - val_loss: 0.9238 - val_accuracy: 0.6837
# Epoch 47/50
# 359/359 [==============================] - ETA: 0s - loss: 0.7355 - accuracy: 0.7244
# Epoch 47: val_accuracy did not improve from 0.68366
# 359/359 [==============================] - 428s 1s/step - loss: 0.7355 - accuracy: 0.7244 - val_loss: 0.9718 - val_accuracy: 0.6571
# Epoch 48/50
# 359/359 [==============================] - ETA: 0s - loss: 0.7245 - accuracy: 0.7321
# Epoch 48: val_accuracy did not improve from 0.68366
# 359/359 [==============================] - 430s 1s/step - loss: 0.7245 - accuracy: 0.7321 - val_loss: 0.9504 - val_accuracy: 0.6592
# Epoch 49/50
# 359/359 [==============================] - ETA: 0s - loss: 0.7200 - accuracy: 0.7324
# Epoch 49: val_accuracy did not improve from 0.68366
# 359/359 [==============================] - 431s 1s/step - loss: 0.7200 - accuracy: 0.7324 - val_loss: 0.9586 - val_accuracy: 0.6697
# Epoch 50/50
# 359/359 [==============================] - ETA: 0s - loss: 0.7115 - accuracy: 0.7338
# Epoch 50: val_accuracy did not improve from 0.68366
# 359/359 [==============================] - 433s 1s/step - loss: 0.7115 - accuracy: 0.7338 - val_loss: 0.9664 - val_accuracy: 0.6508

# %%
# Plot the train and validation loss
train_loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(train_loss) + 1)
plt.plot(epochs, train_loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
train_acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
plt.plot(epochs, train_acc, 'bo', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
import seaborn as sns 
from sklearn.metrics import confusion_matrix

# Get the true labels and predicted labels for the validation set
validation_labels = validation_generator.classes
validation_pred_probs = model.predict(validation_generator)
validation_pred_labels = np.argmax(validation_pred_probs, axis=1)

# Compute the confusion matrix
confusion_mtx = confusion_matrix(validation_labels, validation_pred_labels)
class_names = list(train_generator.class_indices.keys())
sns.set()
sns.heatmap(confusion_mtx, annot=True, fmt='d', cmap='YlGnBu', 
            xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 23/23 [==============================] - 6s 235ms/step
